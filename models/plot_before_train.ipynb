# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
# load csv
main = pd.read_csv('notification_sequence.csv')
column_name = ['gender', 'age', 'department', 'total_usetime',
       'social_usetime', 'communication_usetime', 'entertainment_usetime',
       'news_usetime', 'system_usetime', 'notification_usetime',
       'view_order_top', 'view_order_middle', 'view_order_bottom', 
        'tol_111111', 'tol_1122', 'tol_123', 'tol_222']

for i in column_name[0:12]:
    s = main[i].value_counts()
    plt.bar(x=s.index, height=s.values)
    plt.show()
main
# Out:
#     gender  age department  total_usetime social_usetime  \
# 0        F    2         lb              2              1
# 1        F    2         cs              4              2
# 2        M    2         cs              3              1
# 3        F    2         cs              4              3
# 4        M    2         cs              2              2
# ..     ...  ...        ...            ...            ...
# 843      F    2         bi              4              3
# 844      M    2         lb              3              2
# 845      F    2         lb              2              1
# 846      F    2         cs              3              ?
# 847      M    2         cs              4              4
#
#     communication_usetime entertainment_usetime news_usetime system_usetime  \
# 0                       0                     2            0              0
# 1                       1                     3            0              0
# 2                       0                     1            0              0
# 3                       1                     1            0              0
# 4                       1                     1            0              0
# ..                    ...                   ...          ...            ...
# 843                     2                     3            0              0
# 844                     1                     1            0              0
# 845                     0                     2            0              0
# 846                     ?                     ?            ?              ?
# 847                     1                     1            0              0
#
#     notification_usetime  view_order_top  view_order_middle  \
# 0                      0               1                  2
# 1                      0               1                  2
# 2                      0               1                  2
# 3                      0               1                  2
# 4                      0               1                  2
# ..                   ...             ...                ...
# 843                    0               1                  2
# 844                    0               1                  2
# 845                    0               1                  2
# 846                    ?               1                  2
# 847                    0               1                  2
#
#      view_order_bottom   scenario tol_111111 tol_1122 tol_123 tol_222
# 0                    3    resting     ecswny   ecswny  ecsnwy  ceswny
# 1                    3   wakingup     cwnyse   cwnyes  cnwesy  cwnyes
# 2                    3  commuting     cwsney   cwnsey  csweny  cwnsey
# 3                    3   wakingup     cwnsey   cwnsey  cnwesy  cwnsey
# 4                    3  commuting     secwny   secwny  scenwy  escwny
# ..                 ...        ...        ...      ...     ...     ...
# 843                  3   wakingup     csweny   csewny  csweny  csewny
# 844                  3   wakingup     scnwey   scnwey  scnewy  csnwey
# 845                  3    working     ncwsey   ncswey  ncwesy  cnswey
# 846                  3    resting     nsecwy   nscewy  nescwy  nscewy
# 847                  3  commuting     scewny   scewny  scenwy  csewny
#
# [848 rows x 18 columns]

# %%
x = main['scenario']
y = main['tol_222'].sort_values()
print(x)
print()
print(y)

plt.figure(figsize=(8,8))
plt.scatter(x,y,s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("123.png")
plt.show()
# Out:
# 0        resting
# 1       wakingup
# 2      commuting
# 3       wakingup
# 4      commuting
#          ...
# 843     wakingup
# 844     wakingup
# 845      working
# 846      resting
# 847    commuting
# Name: scenario, Length: 848, dtype: object
#
# 735    censwy
# 606    censwy
# 325    censwy
# 503    censwy
# 343    censwy
#         ...
# 801    swcney
# 555    wyencs
# 282    wyescn
# 444    wyescn
# 528    wynsce
# Name: tol_222, Length: 848, dtype: object
