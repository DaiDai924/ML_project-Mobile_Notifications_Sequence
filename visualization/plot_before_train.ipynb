# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
# load csv
main = pd.read_csv('notification_sequence.csv')
column_name = ['gender', 'age', 'department', 'total_usetime',
       'social_usetime', 'communication_usetime', 'entertainment_usetime',
       'news_usetime', 'system_usetime', 'notification_usetime',
       'view_order_top', 'view_order_middle', 'view_order_bottom', 
        'tol_111111', 'tol_1122', 'tol_123', 'tol_222', 'tol_24', 'tol_15']

for i in column_name:
    s = main[i].value_counts()
    plt.bar(x=s.index, height=s.values)
    plt.show()
main
# Out:
#     gender  age department  total_usetime social_usetime  \
# 0        M    2         sc              2              1
# 1        F    2         bi              4              4
# 2        F    2         cs              1              ?
# 3        F    3         mg              4              2
# 4        F    2         ee              3              1
# ..     ...  ...        ...            ...            ...
# 843      F    2         ee              3              1
# 844      F    4         ot              2              0
# 845      F    2         mg              3              2
# 846      F    2         oe              4              2
# 847      M    2         cs              3              1
#
#     communication_usetime entertainment_usetime news_usetime system_usetime  \
# 0                       0                     2            1              0
# 1                       4                     2            2              0
# ...

# %%
x = main['scenario']
y = main['tol_222'].sort_values()
print(x)
print()
print(y)

plt.figure(figsize=(8,8))
plt.scatter(x,y,s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("123.png")
plt.show()
# Out:
# 0        working
# 1      commuting
# 2       wakingup
# 3      commuting
# 4      commuting
#          ...
# 843      working
# 844     wakingup
# 845      working
# 846      working
# 847     wakingup
# Name: scenario, Length: 848, dtype: object
#
# 226    censwy
# 539    censwy
# 181    censwy
# 477    censwy
# 684    censwy
#         ...
# 82     swcney
# 311    wyencs
# 149    wyescn
# 49     wyescn
# 162    wynsce
# Name: tol_222, Length: 848, dtype: object
